# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
fx=pd.read_csv('Datasets/xdata.csv')
fy=pd.read_csv('Datasets/ydata.csv')

# %%
x=fx.values
y=fy.values

# %%
x=x[:,1:]
y=y[:,1:]

# %%
y=y.reshape((-1,))

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
query=np.array([2,3])
plt.scatter(query[0],query[1],c='red')
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %% [markdown]
# # Start with KNN code

# %%
def distance(x1,x2):
    return np.sqrt(sum((x1-x2)**2))

# %%
def knn(x,y,querypoint,k=5):
    vals=[]
    
    #Pick K Nearest Neighbours
    
    for i in range(x.shape[0]):
        d=distance(querypoint,x[i])
        vals.append((d,y[i]))
        
    #print(vals)
    
    #sort array and find kn points
    
    vals=sorted(vals)
    
    vals=vals[:k]
    
    #Majority Vote
    
    vals=np.array(vals)
    
    new_values=np.unique(vals[:,1],return_counts=True)
    
    #Index of max count
    index=new_values[1].argmax()
    
    #Map this index with my data
    pred=new_values[0][index]
    
    
    return pred

# %%
knn(x,y,[2,3])
# Out:
# 0.0

# %%
knn(x,y,[0,1])
# Out:
# 1.0
